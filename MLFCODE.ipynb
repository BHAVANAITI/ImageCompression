# %% [markdown]
# <a href="https://colab.research.google.com/github/BHAVANAITI/ImageCompression/blob/master/MLFCODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5caea82-c0e0-42f5-9ea4-b2ba9aa392ec" name="files[]" multiple disabled />
#      <output id="result-d5caea82-c0e0-42f5-9ea4-b2ba9aa392ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tiger.png to tiger (1).png

# %%
from skimage import io
import numpy as np
import numpy.matlib

image = io.imread('tiger.png')
io.imshow(image)
io.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:1334: MatplotlibDeprecationWarning:
# box-forced
#   "2.2", "box-forced", obj_type="keyword argument")

# %%
rows = image.shape[0]
cols = image.shape[1]
image = image/255
X = image.reshape(image.shape[0]*image.shape[1],3)

# %%
K = 16 #number of clusters
max_iters = 50 #number of times the k-mean should run

# %%
import random
def init_centroids(X,K):
    c = random.sample(list(X),K)
    return c

# %%
def closest_centroids(X,c):
    K = np.size(c,0)
    idx = np.zeros((np.size(X,0),1))
    arr = np.empty((np.size(X,0),1))
    for i in range(0,K):
        y = c[i]
        temp = np.ones((np.size(X,0),1))*y
        b = np.power(np.subtract(X,temp),2)
        a = np.sum(b,axis = 1)
        a = np.asarray(a)
        a.resize((np.size(X,0),1))
        #print(np.shape(a))
        arr = np.append(arr, a, axis=1)
    arr = np.delete(arr,0,axis=1)
    idx = np.argmin(arr, axis=1)
    return idx

# %%
def compute_centroids(X,idx,K):
    n = np.size(X,1)
    centroids = np.zeros((K,n))
    for i in range(0,K):
        ci = idx==i
        ci = ci.astype(int)
        total_number = sum(ci);
        ci.resize((np.size(X,0),1))
        total_matrix = np.matlib.repmat(ci,1,n)
        ci = np.transpose(ci)
        total = np.multiply(X,total_matrix)
        centroids[i] = (1/total_number)*np.sum(total,axis=0)
    return centroids

# %%
def run_kMean(X,initial_centroids,max_iters):
    m = np.size(X,0)
    n = np.size(X,1)
    K = np.size(initial_centroids,0)
    centroids = initial_centroids
    previous_centroids = centroids
    idx = np.zeros((m,1))
    for i in range(1,max_iters):
        idx = closest_centroids(X,centroids)
        centroids = compute_centroids(X,idx,K)
    return centroids,idx

# %%
initial_centroids = init_centroids(X,K)
centroids,idx = run_kMean(X,initial_centroids,max_iters)
#idx.resize((np.size(X,0),1))
print(np.shape(centroids))
print(np.shape(idx))
# Out:
# (16, 3)
# (853776,)

# %%
idx = closest_centroids(X,centroids)
X_recovered = centroids[idx]
print(np.shape(X_recovered))
X_recovered = np.reshape(X_recovered, (rows, cols, 3))
print(np.shape(X_recovered))
# Out:
# (853776, 3)
# (693, 1232, 3)

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-331d3ca7-c78c-4d65-a04f-75a10c71a63a" name="files[]" multiple disabled />
#      <output id="result-331d3ca7-c78c-4d65-a04f-75a10c71a63a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tiger_small.png to tiger_small.png

# %%
import imageio
im = imageio.imread('tiger_small.jpg')
im.shape  # im is a numpy array
# Out:
# (693, 1232, 3)

# %%
imageio.imwrite('tiger_small.jpg', X_recovered)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
image_compressed = io.imread('tiger_small.jpg')
io.imshow(image_compressed)
io.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:1334: MatplotlibDeprecationWarning:
# box-forced
#   "2.2", "box-forced", obj_type="keyword argument")

# %%
import os
info = os.stat('tiger.png')
print("size of image before running K-mean algorithm: ",info.st_size/1024,"KB")
info = os.stat('tiger_small.jpg')
print("size of image after running K-mean algorithm: ",info.st_size/1024,"KB")
# Out:
# size of image before running K-mean algorithm:  1077.625 KB
# size of image after running K-mean algorithm:  131.29296875 KB
